# %%
import pandas as pd
import requests
import numpy as np
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
from bs4 import BeautifulSoup


from opencage.geocoder import OpenCageGeocode
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans
from pandas import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#Read the data from Wikipedia.

data = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# %%
print(len(data))
# Out:
# 3

# %%
# Find the correct table.

wiki = data[0]
wiki
# Out:
#                                                     0  \
# 0                                    M1A Not assigned
# 1                   M1B Scarborough (Malvern / Rouge)
# 2   M1C Scarborough (Rouge Hill / Port Union / Hig...
# 3   M1E Scarborough (Guildwood / Morningside / Wes...
# 4                            M1G Scarborough (Woburn)
# 5                         M1H Scarborough (Cedarbrae)
# 6               M1J Scarborough (Scarborough Village)
# 7   M1K Scarborough (Kennedy Park / Ionview / East...
# 8   M1L Scarborough (Golden Mile / Clairlea / Oakr...
# 9   M1M Scarborough (Cliffside / Cliffcrest / Scar...
# 10     M1N Scarborough (Birch Cliff / Cliffside West)
# 11  M1P Scarborough (Dorset Park / Wexford Heights...
# 12               M1R Scarborough (Wexford / Maryvale)
# 13                        M1S Scarborough (Agincourt)
# 14  M1T Scarborough (Clarks Corners / Tam O'Shante...
# 15  M1V Scarborough (Milliken / Agincourt North / ...
# 16   M1W Scarborough (Steeles West / L'Amoreaux West)
# 17                      M1X Scarborough (Upper Rouge)
# 18                                   M1Y Not assigned
# 19                                   M1Z Not assigned
#
#                                                   1  \
# 0                                  M2A Not assigned
# 1                                  M2B Not assigned
# 2                                  M2C Not assigned
# 3                                  M2E Not assigned
# 4                                  M2G Not assigned
# 5                M2H North York (Hillcrest Village)
# 6   M2J North York (Fairview / Henry Farm / Oriole)
# 7                  M2K North York (Bayview Village)
# 8        M2L North York (York Mills / Silver Hills)
# 9         M2M North York (Willowdale / Newtonbrook)
# 10                M2N North York (Willowdale) South
# 11                 M2P North York (York Mills West)
# 12                 M2R North York (Willowdale) West
# 13                                 M2S Not assigned
# 14                                 M2T Not assigned
# 15                                 M2V Not assigned
# 16                                 M2W Not assigned
# 17                                 M2X Not assigned
# 18                                 M2Y Not assigned
# 19                                 M2Z Not assigned
#
#                                                     2  \
# 0                          M3A North York (Parkwoods)
# 1                    M3B North York (Don Mills) North
# 2   M3C North York (Don Mills) South (Flemingdon P...
# 3                                    M3E Not assigned
# 4                                    M3G Not assigned
# 5   M3H North York (Bathurst Manor / Wilson Height...
# 6   M3J North York (Northwood Park / York University)
# 7       M3K North York (Downsview) East (CFB Toronto)
# 8                     M3L North York (Downsview) West
# 9                  M3M North York (Downsview) Central
# 10               M3N North York (Downsview) Northwest
# 11                                   M3P Not assigned
# 12                                   M3R Not assigned
# 13                                   M3S Not assigned
# 14                                   M3T Not assigned
# 15                                   M3V Not assigned
# 16                                   M3W Not assigned
# 17                                   M3X Not assigned
# 18                                   M3Y Not assigned
# 19                                   M3Z Not assigned
#
#                                                     3  \
# 0                   M4A North York (Victoria Village)
# 1    M4B East York (Parkview Hill / Woodbine Gardens)
# 2                    M4C East York (Woodbine Heights)
# 3                      M4E East Toronto (The Beaches)
# 4                             M4G East York (Leaside)
# 5                    M4H East York (Thorncliffe Park)
# 6      M4J East York East Toronto (The Danforth East)
# 7    M4K East Toronto (The Danforth West / Riverdale)
# 8   M4L East Toronto (India Bazaar / The Beaches W...
# 9                  M4M East Toronto (Studio District)
# 10                M4N Central Toronto (Lawrence Park)
# 11             M4P Central Toronto (Davisville North)
# 12           M4R Central Toronto (North Toronto West)
# 13                   M4S Central Toronto (Davisville)
# 14  M4T Central Toronto (Moore Park / Summerhill E...
# 15  M4V Central Toronto (Summerhill West / Rathnel...
# 16                    M4W Downtown Toronto (Rosedale)
# 17  M4X Downtown Toronto (St. James Town / Cabbage...
# 18        M4Y Downtown Toronto (Church and Wellesley)
# 19                                   M4Z Not assigned
#
#                                                     4  \
# 0   M5A Downtown Toronto (Regent Park / Harbourfront)
# 1     M5B Downtown Toronto (Garden District, Ryerson)
# 2               M5C Downtown Toronto (St. James Town)
# 3                  M5E Downtown Toronto (Berczy Park)
# 4           M5G Downtown Toronto (Central Bay Street)
# 5   M5H Downtown Toronto (Richmond / Adelaide / King)
# 6   M5J Downtown Toronto (Harbourfront East / Unio...
# 7   M5K Downtown Toronto (Toronto Dominion Centre ...
# 8   M5L Downtown Toronto (Commerce Court / Victori...
# 9   M5M North York (Bedford Park / Lawrence Manor ...
# 10                     M5N Central Toronto (Roselawn)
# 11     M5P Central Toronto (Forest Hill North & West)
# 12  M5R Central Toronto (The Annex / North Midtown...
# 13  M5S Downtown Toronto (University of Toronto / ...
# 14  M5T Downtown Toronto (Kensington Market / Chin...
# 15  M5V Downtown Toronto (CN Tower / King and Spad...
# 16  M5W Downtown Toronto Stn A PO Boxes 25 The Esp...
# 17  M5X Downtown Toronto (First Canadian Place / U...
# 18                                   M5Y Not assigned
# 19                                   M5Z Not assigned
#
#                                                     5  \
# 0   M6A North York (Lawrence Manor / Lawrence Heig...
# 1                          M6B North York (Glencairn)
# 2                       M6C York (Humewood-Cedarvale)
# 3                      M6E York (Caledonia-Fairbanks)
# 4                     M6G Downtown Toronto (Christie)
# 5    M6H West Toronto (Dufferin / Dovercourt Village)
# 6        M6J West Toronto (Little Portugal / Trinity)
# 7   M6K West Toronto (Brockton / Parkdale Village ...
# 8   M6L North York (North Park / Maple Leaf Park /...
# 9   M6M York (Del Ray / Mount Dennis / Keelsdale a...
# 10          M6N York (Runnymede / The Junction North)
# 11  M6P West Toronto (High Park / The Junction South)
# 12         M6R West Toronto (Parkdale / Roncesvalles)
# 13             M6S West Toronto (Runnymede / Swansea)
# 14                                   M6T Not assigned
# 15                                   M6V Not assigned
# 16                                   M6W Not assigned
# 17                                   M6X Not assigned
# 18                                   M6Y Not assigned
# 19                                   M6Z Not assigned
#
#                                                     6  \
# 0    M7A Queen's Park (Ontario Provincial Government)
# 1                                    M7B Not assigned
# 2                                    M7C Not assigned
# 3                                    M7E Not assigned
# 4                                    M7G Not assigned
# 5                                    M7H Not assigned
# 6                                    M7J Not assigned
# 7                                    M7K Not assigned
# 8                                    M7L Not assigned
# 9                                    M7M Not assigned
# 10                                   M7N Not assigned
# 11                                   M7P Not assigned
# 12  M7R Mississauga Canada Post Gateway Processing...
# 13                                   M7S Not assigned
# 14                                   M7T Not assigned
# 15                                   M7V Not assigned
# 16                                   M7W Not assigned
# 17                                   M7X Not assigned
# 18  M7Y East Toronto Business reply mail Processin...
# 19                                   M7Z Not assigned
#
#                                                     7  \
# 0                                    M8A Not assigned
# 1                                    M8B Not assigned
# 2                                    M8C Not assigned
# 3                                    M8E Not assigned
# 4                                    M8G Not assigned
# 5                                    M8H Not assigned
# 6                                    M8J Not assigned
# 7                                    M8K Not assigned
# 8                                    M8L Not assigned
# 9                                    M8M Not assigned
# 10                                   M8N Not assigned
# 11                                   M8P Not assigned
# 12                                   M8R Not assigned
# 13                                   M8S Not assigned
# 14                                   M8T Not assigned
# 15  M8V Etobicoke (New Toronto / Mimico South / Hu...
# 16            M8W Etobicoke (Alderwood / Long Branch)
# 17  M8X Etobicoke (The Kingsway / Montgomery Road ...
# 18  M8Y Etobicoke (Old Mill South / King's Mill Pa...
# 19  M8Z Etobicoke (Mimico NW / The Queensway West ...
#
#                                                     8
# 0                    M9A Etobicoke (Islington Avenue)
# 1   M9B Etobicoke (West Deane Park / Princess Gard...
# 2   M9C Etobicoke (Eringate / Bloordale Gardens / ...
# 3                                    M9E Not assigned
# 4                                    M9G Not assigned
# 5                                    M9H Not assigned
# 6                                    M9J Not assigned
# 7                                    M9K Not assigned
# 8                      M9L North York (Humber Summit)
# 9                  M9M North York (Humberlea / Emery)
# 10                                  M9N York (Weston)
# 11                          M9P Etobicoke (Westmount)
# 12  M9R Etobicoke (Kingsview Village / St. Phillip...
# 13                                   M9S Not assigned
# 14                                   M9T Not assigned
# 15  M9V Etobicoke (South Steeles / Silverstone / H...
# 16  M9W Etobicoke Northwest (Clairville / Humberwo...
# 17                                   M9X Not assigned
# 18                                   M9Y Not assigned
# 19                                   M9Z Not assigned

# %%
import pandas as pd

def get_first_three_chars_and_substring(wiki):
    # Create empty lists to store the results
    postalcode_list = []
    borough_list = []

    # Iterate through each column in the DataFrame
    for col in wiki:
        # Retrieve the first 3 characters of each string in the column and store in a list
        col_values = wiki[col].astype(str).apply(lambda x: x[:3]).tolist()
        postalcode_list.append(col_values)

        # Retrieve the substring from the 4th place value till the bracket open symbol "("
        substr_values = wiki[col].astype(str).apply(lambda x: x[4:x.find(' (')] if ' (' in x else x[4:]).tolist()
        borough_list.append(substr_values)

    return postalcode_list, borough_list


# Get the first 3 characters and substrings of each column and store in separate lists
postalcode_list, borough_list = get_first_three_chars_and_substring(wiki)

print("First 3 characters:", postalcode_list)
print("Substrings:", borough_list)
# Out:
# First 3 characters: [['M1A', 'M1B', 'M1C', 'M1E', 'M1G', 'M1H', 'M1J', 'M1K', 'M1L', 'M1M', 'M1N', 'M1P', 'M1R', 'M1S', 'M1T', 'M1V', 'M1W', 'M1X', 'M1Y', 'M1Z'], ['M2A', 'M2B', 'M2C', 'M2E', 'M2G', 'M2H', 'M2J', 'M2K', 'M2L', 'M2M', 'M2N', 'M2P', 'M2R', 'M2S', 'M2T', 'M2V', 'M2W', 'M2X', 'M2Y', 'M2Z'], ['M3A', 'M3B', 'M3C', 'M3E', 'M3G', 'M3H', 'M3J', 'M3K', 'M3L', 'M3M', 'M3N', 'M3P', 'M3R', 'M3S', 'M3T', 'M3V', 'M3W', 'M3X', 'M3Y', 'M3Z'], ['M4A', 'M4B', 'M4C', 'M4E', 'M4G', 'M4H', 'M4J', 'M4K', 'M4L', 'M4M', 'M4N', 'M4P', 'M4R', 'M4S', 'M4T', 'M4V', 'M4W', 'M4X', 'M4Y', 'M4Z'], ['M5A', 'M5B', 'M5C', 'M5E', 'M5G', 'M5H', 'M5J', 'M5K', 'M5L', 'M5M', 'M5N', 'M5P', 'M5R', 'M5S', 'M5T', 'M5V', 'M5W', 'M5X', 'M5Y', 'M5Z'], ['M6A', 'M6B', 'M6C', 'M6E', 'M6G', 'M6H', 'M6J', 'M6K', 'M6L', 'M6M', 'M6N', 'M6P', 'M6R', 'M6S', 'M6T', 'M6V', 'M6W', 'M6X', 'M6Y', 'M6Z'], ['M7A', 'M7B', 'M7C', 'M7E', 'M7G', 'M7H', 'M7J', 'M7K', 'M7L', 'M7M', 'M7N', 'M7P', 'M7R', 'M7S', 'M7T', 'M7V', 'M7W', 'M7X', 'M7Y', 'M7Z'], ['M8A', 'M8B', 'M8C', 'M8E', 'M8G', 'M8H', 'M8J', 'M8K', 'M8L', 'M8M', 'M8N', 'M8P', 'M8R', 'M8S', 'M8T', 'M8V', 'M8W', 'M8X', 'M8Y', 'M8Z'], ['M9A', 'M9B', 'M9C', 'M9E', 'M9G', 'M9H', 'M9J', 'M9K', 'M9L', 'M9M', 'M9N', 'M9P', 'M9R', 'M9S', 'M9T', 'M9V', 'M9W', 'M9X', 'M9Y', 'M9Z']]
# Substrings: [['Not assigned', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Scarborough', 'Not assigned', 'Not assigned'], ['Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'North York', 'North York', 'North York', 'North York', 'North York', 'North York', 'North York', 'North York', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned'], ['North York', 'North York', 'North York', 'Not assigned', 'Not assigned', 'North York', 'North York', 'North York', 'North York', 'North York', 'North York', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned'], ['North York', 'East York', 'East York', 'East Toronto', 'East York', 'East York', 'East York East Toronto', 'East Toronto', 'East Toronto', 'East Toronto', 'Central Toronto', 'Central Toronto', 'Central Toronto', 'Central Toronto', 'Central Toronto', 'Central Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Not assigned'], ['Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'North York', 'Central Toronto', 'Central Toronto', 'Central Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto', 'Downtown Toronto Stn A PO Boxes 25 The Esplanade', 'Downtown Toronto', 'Not assigned', 'Not assigned'], ['North York', 'North York', 'York', 'York', 'Downtown Toronto', 'West Toronto', 'West Toronto', 'West Toronto', 'North York', 'York', 'York', 'West Toronto', 'West Toronto', 'West Toronto', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned'], ["Queen's Park", 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Mississauga Canada Post Gateway Processing Centre', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'East Toronto Business reply mail Processing Centre 969 Eastern', 'Not assigned'], ['Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Etobicoke', 'Etobicoke', 'Etobicoke', 'Etobicoke', 'Etobicoke'], ['Etobicoke', 'Etobicoke', 'Etobicoke', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'Not assigned', 'North York', 'North York', 'York', 'Etobicoke', 'Etobicoke', 'Not assigned', 'Not assigned', 'Etobicoke', 'Etobicoke Northwest', 'Not assigned', 'Not assigned', 'Not assigned']]

# %%
def get_first_three_chars_and_substring(wiki):
    # Create empty lists to store the results
    postalcode_list = []
    borough_list = []
    neighborhood_list = []

    # Iterate through each column in the DataFrame
    for col in wiki:
        # Retrieve the first 3 characters of each string in the column and store in a list
        col_values = wiki[col].astype(str).apply(lambda x: x[:3]).tolist()
        postalcode_list.append(col_values)

        # Retrieve the substring from the 4th place value till the bracket open symbol "("
        substr_values = wiki[col].astype(str).apply(lambda x: x[4:x.find(' (')] if ' (' in x else x[4:]).tolist()
        borough_list.append(substr_values)

        # Retrieve the values within the brackets
        bracket_values = wiki[col].astype(str).apply(lambda x: x[x.find('(')+1:x.find(')')] if '(' in x and ')' in x else '').tolist()
        neighborhood_list.append(bracket_values)

    return postalcode_list, borough_list, neighborhood_list

# Get the first 3 characters, substrings, and bracket values of each column and store in separate lists
postalcode_list, borough_list, neighborhood_list = get_first_three_chars_and_substring(wiki)

# Flatten the lists
postalcode_flat = [item for sublist in postalcode_list for item in sublist]
borough_flat = [item for sublist in borough_list for item in sublist]
neighborhood_flat = [item for sublist in neighborhood_list for item in sublist]

# Create a DataFrame
toronto = pd.DataFrame({
    'Postal Code': postalcode_flat,
    'Borough': borough_flat,
    'Neighborhood': neighborhood_flat
})

# Drop rows where the column "Borough" has the value "Not assigned"
toronto = toronto[toronto['Borough'] != 'Not assigned']

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Display the resulting DataFrame
toronto
# Out:
#     Postal Code                                            Borough  \
# 1           M1B                                        Scarborough
# 2           M1C                                        Scarborough
# 3           M1E                                        Scarborough
# 4           M1G                                        Scarborough
# 5           M1H                                        Scarborough
# 6           M1J                                        Scarborough
# 7           M1K                                        Scarborough
# 8           M1L                                        Scarborough
# 9           M1M                                        Scarborough
# 10          M1N                                        Scarborough
# 11          M1P                                        Scarborough
# 12          M1R                                        Scarborough
# 13          M1S                                        Scarborough
# 14          M1T                                        Scarborough
# 15          M1V                                        Scarborough
# 16          M1W                                        Scarborough
# 17          M1X                                        Scarborough
# 25          M2H                                         North York
# 26          M2J                                         North York
# 27          M2K                                         North York
# 28          M2L                                         North York
# 29          M2M                                         North York
# 30          M2N                                         North York
# 31          M2P                                         North York
# 32          M2R                                         North York
# 40          M3A                                         North York
# 41          M3B                                         North York
# 42          M3C                                         North York
# 45          M3H                                         North York
# 46          M3J                                         North York
# 47          M3K                                         North York
# 48          M3L                                         North York
# 49          M3M                                         North York
# 50          M3N                                         North York
# 60          M4A                                         North York
# 61          M4B                                          East York
# 62          M4C                                          East York
# 63          M4E                                       East Toronto
# 64          M4G                                          East York
# 65          M4H                                          East York
# 66          M4J                             East York East Toronto
# 67          M4K                                       East Toronto
# 68          M4L                                       East Toronto
# 69          M4M                                       East Toronto
# 70          M4N                                    Central Toronto
# 71          M4P                                    Central Toronto
# 72          M4R                                    Central Toronto
# 73          M4S                                    Central Toronto
# 74          M4T                                    Central Toronto
# 75          M4V                                    Central Toronto
# 76          M4W                                   Downtown Toronto
# 77          M4X                                   Downtown Toronto
# 78          M4Y                                   Downtown Toronto
# 80          M5A                                   Downtown Toronto
# 81          M5B                                   Downtown Toronto
# 82          M5C                                   Downtown Toronto
# 83          M5E                                   Downtown Toronto
# 84          M5G                                   Downtown Toronto
# 85          M5H                                   Downtown Toronto
# 86          M5J                                   Downtown Toronto
# 87          M5K                                   Downtown Toronto
# 88          M5L                                   Downtown Toronto
# 89          M5M                                         North York
# 90          M5N                                    Central Toronto
# 91          M5P                                    Central Toronto
# 92          M5R                                    Central Toronto
# 93          M5S                                   Downtown Toronto
# 94          M5T                                   Downtown Toronto
# 95          M5V                                   Downtown Toronto
# 96          M5W   Downtown Toronto Stn A PO Boxes 25 The Esplanade
# 97          M5X                                   Downtown Toronto
# 100         M6A                                         North York
# 101         M6B                                         North York
# 102         M6C                                               York
# 103         M6E                                               York
# 104         M6G                                   Downtown Toronto
# 105         M6H                                       West Toronto
# 106         M6J                                       West Toronto
# 107         M6K                                       West Toronto
# 108         M6L                                         North York
# 109         M6M                                               York
# 110         M6N                                               York
# 111         M6P                                       West Toronto
# 112         M6R                                       West Toronto
# 113         M6S                                       West Toronto
# 120         M7A                                       Queen's Park
# 132         M7R  Mississauga Canada Post Gateway Processing Centre
# 138         M7Y  East Toronto Business reply mail Processing Ce...
# 155         M8V                                          Etobicoke
# 156         M8W                                          Etobicoke
# 157         M8X                                          Etobicoke
# 158         M8Y                                          Etobicoke
# 159         M8Z                                          Etobicoke
# 160         M9A                                          Etobicoke
# 161         M9B                                          Etobicoke
# 162         M9C                                          Etobicoke
# 168         M9L                                         North York
# 169         M9M                                         North York
# 170         M9N                                               York
# 171         M9P                                          Etobicoke
# 172         M9R                                          Etobicoke
# 175         M9V                                          Etobicoke
# 176         M9W                                Etobicoke Northwest
#
#                                           Neighborhood
# 1                                      Malvern / Rouge
# 2             Rouge Hill / Port Union / Highland Creek
# 3                  Guildwood / Morningside / West Hill
# 4                                               Woburn
# 5                                            Cedarbrae
# 6                                  Scarborough Village
# 7        Kennedy Park / Ionview / East Birchmount Park
# 8                    Golden Mile / Clairlea / Oakridge
# 9    Cliffside / Cliffcrest / Scarborough Village West
# 10                        Birch Cliff / Cliffside West
# 11   Dorset Park / Wexford Heights / Scarborough To...
# 12                                  Wexford / Maryvale
# 13                                           Agincourt
# 14           Clarks Corners / Tam O'Shanter / Sullivan
# 15   Milliken / Agincourt North / Steeles East / L'...
# 16                      Steeles West / L'Amoreaux West
# 17                                         Upper Rouge
# 25                                   Hillcrest Village
# 26                      Fairview / Henry Farm / Oriole
# 27                                     Bayview Village
# 28                           York Mills / Silver Hills
# 29                            Willowdale / Newtonbrook
# 30                                          Willowdale
# 31                                     York Mills West
# 32                                          Willowdale
# 40                                           Parkwoods
# 41                                           Don Mills
# 42                                           Don Mills
# 45   Bathurst Manor / Wilson Heights / Downsview North
# 46                    Northwood Park / York University
# 47                                           Downsview
# 48                                           Downsview
# 49                                           Downsview
# 50                                           Downsview
# 60                                    Victoria Village
# 61                    Parkview Hill / Woodbine Gardens
# 62                                    Woodbine Heights
# 63                                         The Beaches
# 64                                             Leaside
# 65                                    Thorncliffe Park
# 66                                   The Danforth East
# 67                       The Danforth West / Riverdale
# 68                     India Bazaar / The Beaches West
# 69                                     Studio District
# 70                                       Lawrence Park
# 71                                    Davisville North
# 72                                  North Toronto West
# 73                                          Davisville
# 74                        Moore Park / Summerhill East
# 75   Summerhill West / Rathnelly / South Hill / For...
# 76                                            Rosedale
# 77                        St. James Town / Cabbagetown
# 78                                Church and Wellesley
# 80                          Regent Park / Harbourfront
# 81                            Garden District, Ryerson
# 82                                      St. James Town
# 83                                         Berczy Park
# 84                                  Central Bay Street
# 85                          Richmond / Adelaide / King
# 86   Harbourfront East / Union Station / Toronto Is...
# 87           Toronto Dominion Centre / Design Exchange
# 88                     Commerce Court / Victoria Hotel
# 89                  Bedford Park / Lawrence Manor East
# 90                                            Roselawn
# 91                            Forest Hill North & West
# 92               The Annex / North Midtown / Yorkville
# 93                     University of Toronto / Harbord
# 94         Kensington Market / Chinatown / Grange Park
# 95   CN Tower / King and Spadina / Railway Lands / ...
# 96                                      Enclave of M5E
# 97             First Canadian Place / Underground city
# 100                  Lawrence Manor / Lawrence Heights
# 101                                          Glencairn
# 102                                 Humewood-Cedarvale
# 103                                Caledonia-Fairbanks
# 104                                           Christie
# 105                      Dufferin / Dovercourt Village
# 106                          Little Portugal / Trinity
# 107     Brockton / Parkdale Village / Exhibition Place
# 108         North Park / Maple Leaf Park / Upwood Park
# 109  Del Ray / Mount Dennis / Keelsdale and Silvert...
# 110                     Runnymede / The Junction North
# 111                     High Park / The Junction South
# 112                            Parkdale / Roncesvalles
# 113                                Runnymede / Swansea
# 120                      Ontario Provincial Government
# 132                                     Enclave of L4W
# 138                                     Enclave of M4L
# 155     New Toronto / Mimico South / Humber Bay Shores
# 156                            Alderwood / Long Branch
# 157    The Kingsway / Montgomery Road / Old Mill North
# 158  Old Mill South / King's Mill Park / Sunnylea /...
# 159  Mimico NW / The Queensway West / South of Bloo...
# 160                                   Islington Avenue
# 161  West Deane Park / Princess Gardens / Martin Gr...
# 162  Eringate / Bloordale Gardens / Old Burnhamthor...
# 168                                      Humber Summit
# 169                                  Humberlea / Emery
# 170                                             Weston
# 171                                          Westmount
# 172  Kingsview Village / St. Phillips / Martin Grov...
# 175  South Steeles / Silverstone / Humbergate / Jam...
# 176  Clairville / Humberwood / Woodbine Downs / Wes...
