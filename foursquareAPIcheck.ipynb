# %%
# !conda install -c conda-forge geopy --yes 
# !pip install geocoder
# !pip install --upgrade pandas pgeocode
# !pip install pgeocode
# !conda install -c conda-forge folium=0.5.0 --yes
import time                             # For having a time gap in api calls
import pandas as pd                     # For Dataframes, plotting etc
import numpy as np                      # For Mathematical calculation 
import zipfile                          # For unzipping the web scraped files
import os                               # For correcting the file paths
import requests                         # For geting files and jsons
import json                             # For reading and wrangling json files
from bs4 import BeautifulSoup           # For scraping html data from websites
from pandas import json_normalize       # For formatting the jsons readable
import folium                           # For plotting maps
import matplotlib.pyplot as plt                # For plotting charts
import matplotlib.cm as cm              # For functions to handle colormaps
import matplotlib.colors as colors      # For colour maps
import pgeocode                         # For getting lat and lon for postal codes
from geopy.geocoders import Nominatim   # For address into latitude and longitude values on maps
from sklearn.cluster import KMeans      # import k-means from clustering stage
import warnings                         # For ignoreing all warnings 
from api_key import google_key          # For importing the API key hidden in the gitignore
from api_key import places_api_key
from pprint import pprint               # For printing json
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# 11126	Business and Professional Services > Office > Corporate Coffee Shop
# 13032	Dining and Drinking > Cafe, Coffee, and Tea House
# 13033	Dining and Drinking > Cafe, Coffee, and Tea House > Bubble Tea Shop
# 13034	Dining and Drinking > Cafe, Coffee, and Tea House > Café
# 13035	Dining and Drinking > Cafe, Coffee, and Tea House > Coffee Shop
# 13036	Dining and Drinking > Cafe, Coffee, and Tea House > Tea Room
# 13063	Dining and Drinking > Cafe, Coffee, and Tea House > Pet Café
# 13372	Dining and Drinking > Restaurant > Turkish Restaurant > Turkish Coffeehouse

toronto_data = pd.read_csv('extracted_files/toronto_data.csv')

# Create a Nominatim instance for Canada
nomi = pgeocode.Nominatim('CA')

# Create new columns for latitude and longitude
toronto_data['Latitude'] = None
toronto_data['Longitude'] = None

# Iterate over each row to get the latitude and longitude
for index, row in toronto_data.iterrows():
    location = nomi.query_postal_code(row['Postal Code'])
    toronto_data.at[index, 'Latitude'] = location.latitude
    toronto_data.at[index, 'Longitude'] = location.longitude

# Your Foursquare API credentials
def get_coffee_shops(latitude, longitude, radius=500, categories="13032,13033,13034,13035,13036,13063,13072"):
    url = "https://api.foursquare.com/v3/places/search"
    headers = {
        "Accept": "application/json",
        "Authorization": places_api_key
    }
    params = {
        "ll": f"{latitude},{longitude}",
        "radius": radius,
        "categories": categories,  # Category for coffee shops
        "limit": 50  # Limit to 100 results
    }
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        coffee_shop_names = [place['name'] for place in data['results']]
        return len(coffee_shop_names), coffee_shop_names
    else:
        print(f"Failed to fetch data: {response.status_code}")
        return 0, []
# Add new columns for the number of coffee shops and their names
toronto_data['Coffee Counts'] = 0
toronto_data['Coffee Names'] = None
# Iterate over each row to get the number and names of coffee shops
for index, row in toronto_data.iterrows():
    if pd.notna(row['Latitude']) and pd.notna(row['Longitude']):
        num_coffee_shops, coffee_shop_names = get_coffee_shops(row['Latitude'], row['Longitude'])
        toronto_data.at[index, 'Coffee Counts'] = num_coffee_shops
        toronto_data.at[index, 'Coffee Names'] = ', '.join(coffee_shop_names)
# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 500)
# Display the updated DataFrame
toronto_data
# Out:
#    Postal Code                 Borough                                       Neighborhood Latitude Longitude  Population  Average Income  Cafe Counts                                         Cafe Names  Coffee Counts                                       Coffee Names
# 0          M1B             Scarborough                                    Malvern / Rouge  43.8113   -79.193     65555.0         69126.0            0                                                NaN              0
# 1          M1C             Scarborough           Rouge Hill / Port Union / Highland Creek  43.7878  -79.1564     35642.0        109785.0            0                                                NaN              0
# 2          M1E             Scarborough                Guildwood / Morningside / West Hill  43.7678  -79.1866     48033.0         62047.0            4       Tim Hortons, Eggsmart, McDonald's, Mr. Puffs              4  Tim Hortons, Kapit Bahay, Wok Stop Chinese Res...
# 3          M1G             Scarborough                                             Woburn  43.7712  -79.2144     30894.0         54450.0            0                                                NaN              1                                 Korean Grill House
# 4          M1H             Scarborough                                          Cedarbrae  43.7686  -79.2389     23964.0         58492.0            0                                                NaN              0
# 5          M1J             Scarborough                                Scarborough Village  43.7464  -79.2323     37002.0         54507.0            0                                                NaN              0
# 6          M1K             Scarborough      Kennedy Park / Ionview / East Birchmount Park  43.7298  -79.2639     48175.0         53260.0            1                                        Tim Hortons              5  Tim Hortons, Tagpuan Inc, Hakka No 1 Restauran...
# 7          M1L             Scarborough                  Golden Mile / Clairlea / Oakridge  43.7122  -79.2843     35833.0         56779.0            2                           Tim Hortons, Tim Hortons              3         Tim Hortons, Bakery on the Go, Tim Hortons
# 8          M1M             Scarborough  Cliffside / Cliffcrest / Scarborough Village West  43.7247  -79.2312     23258.0         68550.0            1                                        Tim Hortons              5  Tim Hortons, The Village Tea Room, Sushi & Tea...
# 9          M1N             Scarborough                       Birch Cliff / Cliffside West  43.6952  -79.2646     22976.0         73256.0            2                The Birchcliff, City Cottage Market              2                  The Birchcliff, Ume Fashion Sushi
# 10         M1P             Scarborough  Dorset Park / Wexford Heights / Scarborough To...  43.7612  -79.2707     45170.0         56661.0            1                               The Beverage Company              1                                    The Beverage Co
# 11         M1R             Scarborough                                 Wexford / Maryvale  43.7507  -79.3003     30467.0         60881.0            0                                                NaN              0
# 12         M1S             Scarborough                                          Agincourt  43.7946  -79.2644     37663.0         63376.0            0                                                NaN              1                                          Timothy's
# 13         M1T             Scarborough          Clarks Corners / Tam O'Shanter / Sullivan  43.7812  -79.3036     34607.0         53535.0            1                                        Tim Hortons             14  The Royal Chinese Restaurant 避風塘小炒, Kub Khao T...
# 14         M1V             Scarborough  Milliken / Agincourt North / Steeles East / L'...  43.8177  -79.2819     50825.0         64576.0            0                                                NaN              0
# 15         M1W             Scarborough                     Steeles West / L'Amoreaux West  43.8016  -79.3216     47070.0         65190.0            1                                        Tim Hortons              7  Mr Congee Chinese Cuisine, Tim Hortons, Presot...
# 16         M1X             Scarborough                                        Upper Rouge   43.834  -79.2069     14810.0         96107.0            0                                                NaN              0
# 17         M2H              North York                                  Hillcrest Village  43.8015  -79.3577     23396.0         72220.0            0                                                NaN              2  Sky Jade Restaurant, Yoko Japanese Korean Rest...
# 18         M2J              North York                     Fairview / Henry Farm / Oriole  43.7801  -79.3479     61761.0         63471.0            9  Tim Hortons, McDonald's, Starbucks, Fuwa Fuwa ...             14  Aroma Espresso Bar, Starbucks, Thai Express, T...
# 19         M2K              North York                                    Bayview Village  43.7797  -79.3813     25377.0         68015.0            0                                                NaN              0
# 20         M2L              North York                          York Mills / Silver Hills  43.7547  -79.3764     11274.0        115493.0            0                                                NaN              0
# 21         M2M              North York                           Willowdale / Newtonbrook  43.7915  -79.4103     31915.0         60440.0            0                                                NaN              0
# 22         M2N              North York                                         Willowdale  43.7673  -79.4111     75100.0         62919.0           15  Druxy's Famous Deli, Tim Hortons, Starbucks, A...             50  Konjiki Ramen, Saryo Cafe, Aroma Espresso Bar,...
# 23         M2P              North York                                    York Mills West    43.75  -79.3978      7546.0        107520.0            0                                                NaN              0
# 24         M2R              North York                                         Willowdale  43.7786   -79.445     40581.0         56027.0            1                                        Tim Hortons              1                                        Tim Hortons
# 25         M3A              North York                                          Parkwoods  43.7545    -79.33     34361.0         64761.0            0                                                NaN              0
# 26         M3B              North York                                          Don Mills   43.745   -79.359     12880.0        108267.0            0                                                NaN              0
# 27         M3C              North York                                          Don Mills  43.7334  -79.3329     39616.0         57275.0            1                                      DeliMark Café              0
# 28         M3H              North York  Bathurst Manor / Wilson Heights / Downsview North  43.7535  -79.4472     38416.0         71558.0            1                                        Tim Hortons              4  Tim Hortons, Pho Co Duong, Max’s Restaurant, T...
# 29         M3J              North York                   Northwood Park / York University  43.7694  -79.4921     26600.0         54031.0            1                                RC Coffee Robo Cafe              4  Red Soul Japanese Restaurant, Desi Village, Ti...
# 30         M3K              North York                                          Downsview   43.739  -79.4692      7865.0         62635.0            0                                                NaN              0
# 31         M3L              North York                                          Downsview  43.7334  -79.5116     19263.0         59669.0            0                                                NaN              1                           Churrasqueira Sao Miguel
# 32         M3M              North York                                          Downsview  43.7319  -79.4928     24906.0         55099.0            0                                                NaN              0
# 33         M3N              North York                                          Downsview  43.7568   -79.521     40846.0         47650.0            6  Tim Hortons, Soobrian cafe, Tim Hortons, Tim H...              8  Pho Com Vietnam, Tim Hortons, China Wok Super ...
# 34         M4A              North York                                   Victoria Village  43.7276  -79.3148     14589.0         54905.0            2                           Tim Hortons, Tim Hortons              3               Tim Hortons, Best Hakka, Tim Hortons
# 35         M4B               East York                   Parkview Hill / Woodbine Gardens  43.7063  -79.3094     18612.0         60749.0            4  Nostalgia Coffee Company, Tea Room, Cozy Café ...              6  Second Cup, Du Cafe, Nostalgia Coffee Co, Momo...
# 36         M4C               East York                                   Woodbine Heights  43.6913  -79.3116     46440.0         60646.0            1                           Old's Cool General Store              2                     Hakka Fire, Family Bakery Cafe
# 37         M4E            East Toronto                                        The Beaches  43.6784  -79.2941     25473.0         94587.0            3  Tim Hortons, Black Dog Cafe, The Black Canary ...              4  Tim Hortons, Sullivan's Fine Chocolates and Te...
# 38         M4G               East York                                            Leaside  43.7124  -79.3644     19598.0        115833.0            4  Starbucks, Tim Hortons, Charmaine Sweets, ÜNI ...              7  Kintako Japanese Restaurant, Tao Northern Chin...
# 39         M4H               East York                                   Thorncliffe Park  43.7059  -79.3464     18698.0         43945.0            3  Tim Hortons, Thorncliffe Park Cafe, Common Gro...              7  Faley Restaurant, Original Barrio Fiesta, Hakk...
# 40         M4J  East York East Toronto                                  The Danforth East  43.6872  -79.3368     35128.0         72720.0            0                                                NaN              1                                     The Red Rocket
# 41         M4K            East Toronto                      The Danforth West / Riverdale  43.6803  -79.3538     30913.0         65948.0           13  Demetres Danforth, Broadview Espresso, Second ...             28  7 Numbers, Tsaa Tea Shop, Momo Hut & Gardens, ...
# 42         M4L            East Toronto                    India Bazaar / The Beaches West  43.6693  -79.3155     32218.0         81014.0            5  Country Style, Simple Coffee, The Sunset Marke...              6  O Sushi, Glory Hole Doughnuts, Lazy Daisy's Ca...
# 43         M4M            East Toronto                                    Studio District  43.6561  -79.3406     25052.0         75412.0            1                                        Tim Hortons              4  Mountain View Estates Coffee Cie, Tim Hortons,...
# 44         M4N         Central Toronto                                      Lawrence Park  43.7301  -79.3935     16058.0        137758.0            0                                                NaN              1                                     Dim Sum Deluxe
# 45         M4P         Central Toronto                                   Davisville North  43.7135  -79.3887     25057.0         61036.0            1                              L'amour Cafe & Pastry              2                    Sahara & Co, Songha Kung Fu Tea
# 46         M4R         Central Toronto                                 North Toronto West  43.7143  -79.4065     11909.0         94208.0            0                                                NaN              1                                       Issimi sushi
# 47         M4S         Central Toronto                                         Davisville   43.702  -79.3853     30754.0         75520.0            4  Jules Cafe Patisserie, Tim Hortons, Daphne's A...             15  Jules Cafe Patisserie, Thobors Boulangerie Pat...
# 48         M4T         Central Toronto                       Moore Park / Summerhill East  43.6899  -79.3853     10332.0         96571.0            0                                                NaN              0
# 49         M4V         Central Toronto  Summerhill West / Rathnelly / South Hill / For...  43.6861  -79.4025     19273.0         85487.0            3          Starbucks, South Hill Market, Tim Hortons              3    Tim Hortons, Favourite Pasttime Cafe, Starbucks
# 50         M4W        Downtown Toronto                                           Rosedale  43.6827   -79.373     15296.0        101146.0            0                                                NaN              1                                       Dolce Bakery
# 51         M4X        Downtown Toronto                       St. James Town / Cabbagetown  43.6684  -79.3689     19896.0         40291.0            7  JetFuel Coffee Shop, Park Snacks, Tim Hortons,...             21  Cabbagetown Brew, Kibo Sushi House, Jet Fuel C...
# 52         M4Y        Downtown Toronto                               Church and Wellesley  43.6656   -79.383     36319.0         52167.0           37  7 West Cafe, McDonald's, Tim Hortons, McDonald...             50  The Alley, Starbucks, Church Street Espresso, ...
# 53         M5A        Downtown Toronto                         Regent Park / Harbourfront  43.6555  -79.3626     48978.0         52623.0           10  Sumach Espresso, Figs Breakfast Lunch, Rooster...             26  Roselle Desserts, Tandem Coffee, Sumach Espres...
# 54         M5B        Downtown Toronto                           Garden District, Ryerson  43.6572  -79.3783     17422.0         49856.0           60  Tim Hortons, Balzac's Image Arts, Eggsmart, St...             50  Hokkaido Ramen Santouka, Page One Cafe, Banh M...
# 55         M5C        Downtown Toronto                                     St. James Town  43.6513  -79.3756      3149.0         83872.0           60  Tim Hortons, Tim Hortons, Dineen Coffee Co., F...             50  Versus Coffee, Fahrenheit Coffee, Dineen Coffe...
# 56         M5E        Downtown Toronto                                        Berczy Park  43.6456  -79.3754     11779.0         89969.0           56  Tim Hortons, The Market by Longo's at Brookfie...             50  Sukho Thai, Chotto Matte, Pilot Coffee Roaster...
# 57         M5G        Downtown Toronto                                 Central Bay Street  43.6564   -79.386      9751.0         49696.0           60  Avenue Cafe + Bistro, Eggsmart, Tim Hortons, C...             50  Jimmy's Coffee, Hailed Coffee, Tim Hortons, Ko...
# 58         M5H        Downtown Toronto                         Richmond / Adelaide / King  43.6496  -79.3833      3248.0         86101.0           60  Tim Hortons, Starbucks, Aroma Espresso Bar, Di...             50  Cafe Landwer, Sam James Coffee Bar, Bosk, Pilo...
# 59         M5J        Downtown Toronto  Harbourfront East / Union Station / Toronto Is...   43.623  -79.3936     16879.0         85077.0            0                                                NaN              0
# 60         M5M              North York                 Bedford Park / Lawrence Manor East  43.7335  -79.4177     25495.0        136982.0            8  Tim Hortons, McDonald's, Eggsmart, Tim Hortons...             17  Aroma Espresso Bar, Tim Hortons, Sakura Garden...
# 61         M5N         Central Toronto                                           Roselawn  43.7113  -79.4195     16154.0         94106.0            0                                                NaN              0
# 62         M5P         Central Toronto                           Forest Hill North & West  43.6966   -79.412     19791.0         85309.0            1                                        Tim Hortons              1                                        Tim Hortons
# 63         M5R         Central Toronto              The Annex / North Midtown / Yorkville  43.6736  -79.4035     26197.0         68881.0            9  Ezra's Pound, Tim Hortons, Country Style, Firs...             10  MIMI Chinese, Haute Coffee, Tim Hortons, Aboki...
# 64         M5S        Downtown Toronto                    University of Toronto / Harbord  43.6629  -79.3987     17074.0         52966.0           20  Second Cup Café, Almond Butterfly Bakeshop & C...             32  Yasu, Almond Butterfly, Gyubee, Second Cup Cof...
# 65         M5T        Downtown Toronto        Kensington Market / Chinatown / Grange Park  43.6541  -79.3978     17903.0         43986.0           40  King's Café, Dark Horse Espresso Bar, Wanda's ...             50  Dumpling House Restaurant, Moonbean Coffee Co,...
# 66         M5V        Downtown Toronto  CN Tower / King and Spadina / Railway Lands / ...  43.6404  -79.3995     59912.0         77752.0           23  Starbucks, McDonald's, Tim Hortons, Quantum Co...             35  Sansotei Ramen, CAFE Dispensary, Tim Hortons, ...
# 67         M6A              North York                  Lawrence Manor / Lawrence Heights  43.7223  -79.4504     22380.0         53933.0            9  Tim Hortons, Michel's Bakery Café, Starbucks, ...             19  Starbucks, Yuki Japanese & Korean Restaurant, ...
# 68         M6B              North York                                          Glencairn  43.7081  -79.4479     28534.0         66282.0            6  McDonald's, Tony's Espresso Bar, Cafe 513., Cl...              7  Miyako Sushi, Kokoro Sushi Restaurant, Sweet H...
# 69         M6C                    York                                 Humewood-Cedarvale  43.6915  -79.4307     23997.0         69058.0            2                      Hunter Coffee Shop, Sady cafe              1                                 Coffee Time Donuts
# 70         M6E                    York                                Caledonia-Fairbanks  43.6889  -79.4507     37684.0         61113.0            0                                                NaN              1                                        SNSD's home
# 71         M6G        Downtown Toronto                                           Christie  43.6683  -79.4205     30600.0         72363.0            7  Contra Café, Fiesta No Siesta, ROSALU snackbar...              8  Contra Cafe, Faema Caffe, Morellina's, Gobo Su...
# 72         M6H            West Toronto                      Dufferin / Dovercourt Village  43.6655  -79.4378     43730.0         63550.0            4  Laundry & Lattes, THREE HORSES Cafe & Speed Sh...              3               Golden Gecko, Kuma Sushi, Faema Cafe
# 73         M6J            West Toronto                          Little Portugal / Trinity   43.648  -79.4177     32111.0         71745.0           29  I DEAL COFFEE & WINE, Nova Era Bakery, Bang Ba...             32  Foxley, Oddseoul, Rua Vang Golden Turtle Resta...
# 74         M6K            West Toronto     Brockton / Parkdale Village / Exhibition Place  43.6383  -79.4301     42110.0         54000.0           14  Louie Coffee Shop, Capital Espresso, Rustic Co...             20  The Abbott, Louie - Craft Coffee, Capital Espr...
# 75         M6L              North York         North Park / Maple Leaf Park / Upwood Park  43.7137  -79.4869     20156.0         54933.0            0                                                NaN              0
# 76         M6M                    York  Del Ray / Mount Dennis / Keelsdale and Silvert...  43.6934  -79.4857     42148.0         52730.0            2               Office Coffee Solutions, Tim Hortons              3  Tim Hortons, Office Coffee Solutions Ltd, Home...
# 77         M6N                    York                     Runnymede / The Junction North  43.6748  -79.4839     40252.0         57771.0            2                              Cafe Fado, PCS Repair              2              Senso Cafe Restaurant, Nomo Creations
# 78         M6P            West Toronto                     High Park / The Junction South  43.6605  -79.4633     39870.0         68983.0            1                                          See-Scape              0
# 79         M6R            West Toronto                            Parkdale / Roncesvalles  43.6469  -79.4521     19349.0         78580.0            4  Reunion Coffee Roasters, Extra Butter Coffee, ...             11  Sushi on Roncy, Reunion Island Coffee Bar, Ext...
# 80         M6S            West Toronto                                Runnymede / Swansea  43.6512  -79.4828     34029.0         90288.0           17  Queen's Pasta Café, Coffee Tree Roastery, Seco...             26  Zaza Espresso Bar, Coffee Tree, Yumi Japanese ...
# 81         M8V               Etobicoke     New Toronto / Mimico South / Humber Bay Shores  43.6075  -79.5013     44144.0         61120.0            0                                                NaN              0
# 82         M8W               Etobicoke                            Alderwood / Long Branch  43.6021  -79.5402     22381.0         73201.0            3            Tim Hortons, Nellie's Café, Alba Caffee              7  Silk Road Restaurant, Tim Hortons, Cafe Sport ...
# 83         M8X               Etobicoke    The Kingsway / Montgomery Road / Old Mill North  43.6518  -79.5076     10624.0        119097.0            3  Eggsmart, Cafe Rouge Patisserie, Demetres King...              6  Caffe Demetre, Momiji Sushi Bar, Hot Oven Bake...
# 84         M8Y               Etobicoke  Old Mill South / King's Mill Park / Sunnylea /...  43.6325  -79.4939     21986.0         73673.0            0                                                NaN              0
# 85         M8Z               Etobicoke  Mimico NW / The Queensway West / South of Bloo...  43.6256  -79.5231     19312.0         92456.0            5  Tim Hortons, Hometown Coffee Ltd, Lio's Cafe, ...             10  K&B Sushi, Mandarin Restaurant, Green Mango Ex...
# 86         M9A               Etobicoke                                   Islington Avenue  43.6662  -79.5282     36642.0         75907.0            0                                                NaN              0
# 87         M9B               Etobicoke  West Deane Park / Princess Gardens / Martin Gr...  43.6505  -79.5517     33236.0         88576.0            0                                                NaN              4  Carolina's Cuisina, Far East Chinese Food, The...
# 88         M9C               Etobicoke  Eringate / Bloordale Gardens / Old Burnhamthor...  43.6437  -79.5767     38725.0         77818.0            0                                                NaN              1                                                Joy
# 89         M9L              North York                                      Humber Summit  43.7598  -79.5565     11737.0         62899.0            0                                                NaN              1                                         Stair Star
# 90         M9M              North York                                  Humberlea / Emery  43.7366  -79.5401     24245.0         61884.0            0                                                NaN              0
# 91         M9N                    York                                             Weston  43.7068   -79.517     26059.0         50545.0            0                                                NaN              1                                  Szechuan Szechuan
# 92         M9P               Etobicoke                                          Westmount  43.6949  -79.5323     20645.0         73425.0            2                          Baskin-Robbins, Starbucks              3       Starbucks, Mayflower Chinese Food, Lan Sushi
# 93         M9R               Etobicoke  Kingsview Village / St. Phillips / Martin Grov...  43.6898  -79.5582     33783.0         63032.0            1                                         McDonald's              2                     Gourmet Express, Ichiban Sushi
# 94         M9V               Etobicoke  South Steeles / Silverstone / Humbergate / Jam...  43.7432  -79.5876     53878.0         59760.0            3    Tim Hortons, Tim Hortons, Pam's Coffee & Tea Co              7  Tim Hortons, Kashmir Curry & Biryani House, Mo...
# 95         M9W     Etobicoke Northwest  Clairville / Humberwood / Woodbine Downs / Wes...  43.7144  -79.5909     40977.0         65826.0            3                 Tim Hortons, Xawaash, Lavish Doses              2                      Tim Hortons, Bilal Restaurant
